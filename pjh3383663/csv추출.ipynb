# %%
import pandas as pd

data_dir = "data/PdM/"
df_wavedata = pd.read_csv(data_dir + "ics_asset_wavedata.csv")

# %%
data_5528 = df_wavedata[df_wavedata['asset_id'] == '55285839-9b78-48d8-9f4e-573190ace016']

# %%
data_5528
# Out:
#                                    asset_id  created_at  \
# 39740  55285839-9b78-48d8-9f4e-573190ace016  1704037054
# 39741  55285839-9b78-48d8-9f4e-573190ace016  1704044261
# 39742  55285839-9b78-48d8-9f4e-573190ace016  1704051464
# 39743  55285839-9b78-48d8-9f4e-573190ace016  1704058671
# 39744  55285839-9b78-48d8-9f4e-573190ace016  1704065874
# ...                                     ...         ...
# 42597  55285839-9b78-48d8-9f4e-573190ace016  1724640671
# 42598  55285839-9b78-48d8-9f4e-573190ace016  1724647880
# 42599  55285839-9b78-48d8-9f4e-573190ace016  1724655083
# 42600  55285839-9b78-48d8-9f4e-573190ace016  1724662291
# 42601  55285839-9b78-48d8-9f4e-573190ace016  1724669494
#
#                                               waveform_x  \
# 39740  0,0.005859375,0.017578125,0,0,0.005859375,-0.0...
# 39741  0,0.017578125,-0.017578125,0,0.029296875,0.023...
# 39742  0,0.017578125,0,0.017578125,0,0.017578125,0,0,...
# 39743  0,0.017578125,0,0,0,0.041015625,0.0234375,0.00...
# ...

# %%
df_55 = pd.read_csv("data_5528.csv")

# %%
df_55
# Out:
#                                   asset_id  created_at  \
# 0     55285839-9b78-48d8-9f4e-573190ace016  1704037054
# 1     55285839-9b78-48d8-9f4e-573190ace016  1704044261
# 2     55285839-9b78-48d8-9f4e-573190ace016  1704051464
# 3     55285839-9b78-48d8-9f4e-573190ace016  1704058671
# 4     55285839-9b78-48d8-9f4e-573190ace016  1704065874
# ...                                    ...         ...
# 2857  55285839-9b78-48d8-9f4e-573190ace016  1724640671
# 2858  55285839-9b78-48d8-9f4e-573190ace016  1724647880
# 2859  55285839-9b78-48d8-9f4e-573190ace016  1724655083
# 2860  55285839-9b78-48d8-9f4e-573190ace016  1724662291
# 2861  55285839-9b78-48d8-9f4e-573190ace016  1724669494
#
#                                              waveform_x  \
# 0     0,0.005859375,0.017578125,0,0,0.005859375,-0.0...
# 1     0,0.017578125,-0.017578125,0,0.029296875,0.023...
# 2     0,0.017578125,0,0.017578125,0,0.017578125,0,0,...
# 3     0,0.017578125,0,0,0,0.041015625,0.0234375,0.00...
# ...
